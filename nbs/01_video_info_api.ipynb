# %%
"""This library queries the YouTube API for the list of videos on any given channel and returns the video ids, details,
and stats as a pandas dataframe that can be exported to a .csv"""

# %%
import requests
import json
import pandas as pd

with open(key_file_loc) as f: keys = dict(x.rstrip().split(None,1) for x in f)
    
key = keys['ytapi']

channel_id = "UC3XTzVzaHQEd30rQbuvCtTQ"

# %%
url = "https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id={}&key={}".format(channel_id,key)

# %%
response = requests.get(url)

# %%
file_ = json.loads(response.text)

# %%
playlist = file_['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
if playlist:
    next_page_token = None
    ids = []
    run = True
    while run:
        query = "https://www.googleapis.com/youtube/v3/playlistItems?part=contentDetails&maxResults=50&playlistId={}&key={}".format(playlist, key)
        
        if next_page_token:
            query += "&pageToken={}".format(next_page_token)
        
        response = json.loads((requests.get(query)).text)
        
        for item in response['items']:
            ids.append(item['contentDetails']['videoId'])
            
        try: 
            next_page_token = response['nextPageToken']
        except:
            run = False

# %%
df = pd.DataFrame()

for id_ in ids:

    query = "https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&id={}&key={}".format(id_,key)
    response = json.loads((requests.get(query).text))
    
    dict_ = {
        'channelId' : response['items'][0]['snippet']['channelId'],
        'channelTitle' : response['items'][0]['snippet']['channelTitle'],
        'description' : response['items'][0]['snippet']['description'],
        'title' : response['items'][0]['snippet']['title'],
        'publishedAt' : response['items'][0]['snippet']['publishedAt'],
        'commentCount' : response['items'][0]['statistics']['commentCount'],
        'dislikeCount' : response['items'][0]['statistics']['dislikeCount'],
        'likeCount' : response['items'][0]['statistics']['likeCount'],
        'viewCount' : response['items'][0]['statistics']['viewCount']       
        
    }
    
    df = df.append(dict_, ignore_index=True)

# %%
comment_frame = pd.DataFrame()
ids = [ids[0]]
for id_ in ids:
    
    next_page_token = None
    run = True
    comments = []
    
    while run:
        query = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&maxResults=100&videoId={}&key={}".format(id_,key)
        if next_page_token:
            query += "&pageToken={}".format(next_page_token)
        
        response = json.loads((requests.get(query)).text)
        
        for item in response['items']:
            comments.append(item)
            
        try: 
            next_page_token = response['next_page_token']
        except:
            run = False
    
    for item in comments:
        dict_ = {
            'id' : item['id'],
            'authorChannelUrl' : item['snippet']['topLevelComment']['snippet']['authorChannelUrl'],
            'authorDisplayName' : item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            'likeCount' : item['snippet']['topLevelComment']['snippet']['likeCount'],
            'publishedAt' : item['snippet']['topLevelComment']['snippet']['publishedAt'],
            'textDisplay' : item['snippet']['topLevelComment']['snippet']['textDisplay'],
            'videoId' : item['snippet']['topLevelComment']['snippet']['videoId'],
            'viewerRating' : item['snippet']['topLevelComment']['snippet']['viewerRating'],
            'totalReplyCount' : item['snippet']['totalReplyCount'],
            'isReply' : 0,
            'isReplyTo' : ""
        }
        comment_frame = comment_frame.append(dict_, ignore_index=True)
        
        if dict_['totalReplyCount'] > 0:
            replies = []
            next_page_token = None
            run = True
        
            while run:
                query = "https://www.googleapis.com/youtube/v3/comments?part=snippet&textFormat=plainText&maxResults=100&parentId={}&key={}".format(dict_['id'],key)
                
                if next_page_token:
                    query += "&pageToken={}".format(next_page_token)
                
                response = json.loads((requests.get(query)).text)
                
                for item in response['items']:
                    replies.append(item)
                
                try: 
                    next_page_token = response['nextPageToken']
                except:
                    run = False
            
            for item in replies:
                
                rdict_ = {
                    'id' : item['id'],
                    'authorChannelUrl' : item['snippet']['authorChannelUrl'],
                    'authorDisplayName' : item['snippet']['authorDisplayName'],
                    'likeCount' : item['snippet']['likeCount'],
                    'publishedAt' : item['snippet']['publishedAt'],
                    'textDisplay' : item['snippet']['textDisplay'],
                    'videoId' : dict_['videoId'],
                    'viewerRating' : item['snippet']['viewerRating'],
                    'totalReplyCount' : 0,
                    'isReply' : 1,
                    'isReplyTo' : dict_['authorDisplayName']
                }
                
                comment_frame = comment_frame.append(rdict_, ignore_index = True)

# %%
comment_frame
# Out:
#                                       authorChannelUrl  \
# 0    http://www.youtube.com/channel/UCeIvXrlFTomz__...
# 1    http://www.youtube.com/channel/UCKJL7teoSMFQrw...
# 2    http://www.youtube.com/channel/UCws6FICb7u5g_5...
# 3    http://www.youtube.com/channel/UCAHvjcuCbCJuir...
# 4    http://www.youtube.com/channel/UC1IJrYve0ukJ2z...
# 5    http://www.youtube.com/channel/UCOOkk9nSGCNpat...
# 6    http://www.youtube.com/channel/UCuxfhcpHPymhsz...
# 7    http://www.youtube.com/channel/UCsZkyZOJwEU6RI...
# 8    http://www.youtube.com/channel/UCIdqB2jJPfmau5...
# 9    http://www.youtube.com/channel/UCsqk7v8uOrVxZl...
# 10   http://www.youtube.com/channel/UCKpI4rWDKI2d1g...
# 11   http://www.youtube.com/channel/UCkDNKQ70B4fbxO...
# 12   http://www.youtube.com/channel/UCyDkfu6UWTE5u2...
# 13   http://www.youtube.com/channel/UCcJ8VgghXTDM5g...
# 14   http://www.youtube.com/channel/UCadIgFLPaMuG1T...
# 15   http://www.youtube.com/channel/UCwuVfP2A_C6sFw...
# 16   http://www.youtube.com/channel/UCzBw9R1dOMwOgt...
# 17   http://www.youtube.com/channel/UCYjhHREf-Q-iXq...
# 18   http://www.youtube.com/channel/UC0nINHzY4XY0AN...
# 19   http://www.youtube.com/channel/UCLVdxEXV4Xaqkt...
# 20   http://www.youtube.com/channel/UC7CBc38jeEZBP2...
# 21   http://www.youtube.com/channel/UCaXmW6bK8aGe6q...
# 22   http://www.youtube.com/channel/UCzdYvY_2cx578r...
# 23   http://www.youtube.com/channel/UC5cehnzHy20i49...
# 24   http://www.youtube.com/channel/UCaXmW6bK8aGe6q...
# 25   http://www.youtube.com/channel/UCH2i5819qM2VwY...
# 26   http://www.youtube.com/channel/UCkOj7XTcoS1Zbl...
# 27   http://www.youtube.com/channel/UC4ca9BBoudh0l5...
# 28   http://www.youtube.com/channel/UCbxxRbQ7uvzFto...
# 29   http://www.youtube.com/channel/UCbxxRbQ7uvzFto...
# ..                                                 ...
# 74   http://www.youtube.com/channel/UCSsFPl5kribFgF...
# 75   http://www.youtube.com/channel/UCfQIqZ9ZlO5CG_...
# 76   http://www.youtube.com/channel/UCQ0IQ93iAklEVh...
# 77   http://www.youtube.com/channel/UClCOMJZYEklzsx...
# 78   http://www.youtube.com/channel/UCosa7G3dTxGb6M...
# 79   http://www.youtube.com/channel/UCp4Kfk65GQ9yqT...
# 80   http://www.youtube.com/channel/UC-pHiiW-ojQHhP...
# 81   http://www.youtube.com/channel/UCoDTPaFuGEi6SK...
# 82   http://www.youtube.com/channel/UCQ0IQ93iAklEVh...
# 83   http://www.youtube.com/channel/UC7THKnSnwY5cFy...
# 84   http://www.youtube.com/channel/UCeEGsknFNCp7uf...
# 85   http://www.youtube.com/channel/UCQ0IQ93iAklEVh...
# 86   http://www.youtube.com/channel/UClFEVmBrHmZyhJ...
# 87   http://www.youtube.com/channel/UCOohJUkRu2EGTb...
# 88   http://www.youtube.com/channel/UCfEYkKXi3Ja_Xv...
# 89   http://www.youtube.com/channel/UCsVGHf_H1mCrfa...
# 90   http://www.youtube.com/channel/UC6wv06Wly3UMt9...
# 91   http://www.youtube.com/channel/UCfcLnwFOuOcJZj...
# 92   http://www.youtube.com/channel/UCX1WflR5oYeemc...
# 93   http://www.youtube.com/channel/UCGMufhrTNqpCKp...
# 94   http://www.youtube.com/channel/UChME-wDGibj1Np...
# 95   http://www.youtube.com/channel/UCXx2y0Px8clAFm...
# 96   http://www.youtube.com/channel/UCN0ypSdlnyTntT...
# 97   http://www.youtube.com/channel/UCUwRcElS7l8hI5...
# 98   http://www.youtube.com/channel/UCmFihgtqgpTcsu...
# 99   http://www.youtube.com/channel/UCMdY81yZF452M_...
# 100  http://www.youtube.com/channel/UCwu34rYlXAg7-i...
# 101  http://www.youtube.com/channel/UCM33a7ER5DF_va...
# 102  http://www.youtube.com/channel/UChos8O959F0P04...
# 103  http://www.youtube.com/channel/UCmX_hOfONX0FSU...
#
#             authorDisplayName  \
# 0          MisstressMourtisha
# 1             StudyingForLife
# 2                 fakshen1973
# 3                  AceFailure
# 4               Av arm Online
# 5    This is not My real Name
# 6              Angela Stovall
# 7               Miguel Ortega
# 8                      M Soda
# 9               breeze aleigh
# 10               ODD Anderson
# 11                 Free Golem
# 12                       rick
# 13          Study On Internet
# 14               Ariel Cotton
# 15                  J Johnson
# 16               Todd Rasband
# 17               Steffen Berr
# 18            Bolivian prince
# 19             Sci-Fi Lullaby
# 20             Nikos Mavridis
# 21                  nandy9285
# 22                   cz luver
# 23           CraniumAmbiguity
# 24                  nandy9285
# 25                 GunQuickie
# 26                   Piriathy
# 27             A.E. Vassileva
# 28              eclecticaspie
# 29              eclecticaspie
# ..                        ...
# 74                Keith James
# 75                MrJumbolegz
# 76             Aditya Sanjeev
# 77            Gabe Villarreal
# 78                     Paul B
# 79         ‘Cave Beast Demon'
# 80            robert matthews
# 81                CDGBH CDGBH
# 82             Aditya Sanjeev
# 83              Matheus Silva
# 84             Clint Matthews
# 85             Aditya Sanjeev
# 86                  Abdo Bedo
# 87               Thomas Busse
# 88                   Urs Arlt
# 89              Carol Freitas
# 90                      L. K.
# 91                    Prixels
# 92                 Amarina E.
# 93                 Heidelaffe
# 94                 ootmaster1
# 95                  A Cvetkov
# 96                    gam mal
# 97              Chewy Thomson
# 98             Taneleer Tivan
# 99             Milos Mitrovic
# 100              Nathan Flamm
# 101                BATTERIESc
# 102               Mike Stetka
# 82   CDGBH CDGBH and school shootings are caused by...
# 83   the &quot;u haven&#39;t met america&quot;bit w...               0
# 84   Man you are funny. Hopefully you do know but d...               1
# 85   Drugs and obesity aren't weapons that can kill...
# 86         NRA should be destroyed right now!!! WTF!!!               0
# 87   I&#39;m not a fan of the fake outrage, it turn...               0
# 88   Among all those firearm companies that are adv...               0
# 89               I will never eat a muffin ever again.               0
# 90   NRA-TV is basically like a channel on the inte...               0
# 91   Yeah, defend your country&#39;s metaphorical d...               0
# 92                   Americans are locos... just locos               0
# 93   When I made a 3 weeks roadtrip to the US I was...               1
# 94   well maybe if you do what they ask and dont tr...
# 95                           My god, Merica. My god...               0
# 96   this episode shows 2 things, how homicidal gun...               0
# 97   America&#39;s fetishization of guns is going t...               0
# 98   Guys, no one or thing, not even marijuana, sho...               0
# 99   Don&#39;t ban guns Murica. Continue the natura...               0
# 100  The NRA is the moderate wing of the gun rights...               0
# 101                                         PROPAGANDA               0
# 102  So crazy I watched this video and the next tim...               0
# 103                          Go NRA! F U English cunt!               0
#
#          videoId viewerRating
# 0    LEcbagW4O-s         none
# 1    LEcbagW4O-s         none
# 2    LEcbagW4O-s         none
# 3    LEcbagW4O-s         none
# 4    LEcbagW4O-s         none
# 5    LEcbagW4O-s         none
# 6    LEcbagW4O-s         none
# 7    LEcbagW4O-s         none
# 8    LEcbagW4O-s         none
# 9    LEcbagW4O-s         none
# 10   LEcbagW4O-s         none
# 11   LEcbagW4O-s         none
# 12   LEcbagW4O-s         none
# 13   LEcbagW4O-s         none
# 14   LEcbagW4O-s         none
# 15   LEcbagW4O-s         none
# 16   LEcbagW4O-s         none
# 17   LEcbagW4O-s         none
# 18   LEcbagW4O-s         none
# 19   LEcbagW4O-s         none
# 20   LEcbagW4O-s         none
# 21   LEcbagW4O-s         none
# 22   LEcbagW4O-s         none
# 23   LEcbagW4O-s         none
# 24   LEcbagW4O-s         none
# 25   LEcbagW4O-s         none
# 26   LEcbagW4O-s         none
# 27   LEcbagW4O-s         none
# 28   LEcbagW4O-s         none
# 29   LEcbagW4O-s         none
# ..           ...          ...
# 74   LEcbagW4O-s         none
# 75   LEcbagW4O-s         none
# 76   LEcbagW4O-s         none
# 77   LEcbagW4O-s         none
# 78   LEcbagW4O-s         none
# 79   LEcbagW4O-s         none
# 80   LEcbagW4O-s         none
# 81   LEcbagW4O-s         none
# 82   LEcbagW4O-s         none
# 83   LEcbagW4O-s         none
# 84   LEcbagW4O-s         none
# 85   LEcbagW4O-s         none
# 86   LEcbagW4O-s         none
# 87   LEcbagW4O-s         none
# 88   LEcbagW4O-s         none
# 89   LEcbagW4O-s         none
# 90   LEcbagW4O-s         none
# 91   LEcbagW4O-s         none
# 92   LEcbagW4O-s         none
# 93   LEcbagW4O-s         none
# 94   LEcbagW4O-s         none
# 95   LEcbagW4O-s         none
# 96   LEcbagW4O-s         none
# 97   LEcbagW4O-s         none
# 98   LEcbagW4O-s         none
# 99   LEcbagW4O-s         none
# 100  LEcbagW4O-s         none
# 101  LEcbagW4O-s         none
# 102  LEcbagW4O-s         none
# 103  LEcbagW4O-s         none
#
# [104 rows x 11 columns]
